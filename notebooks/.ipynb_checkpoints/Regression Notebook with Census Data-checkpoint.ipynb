# %% [markdown]
# # Regression Notebook with Census Data
#
# The purpose of this notebook is to find explanatory variables that influence the volume of groundwater testing in California. More information on data and context can be found in the  (1) Background and (2) Data Notion pages to better understand the data being used.
#
# ## Specialty Imports
# * Zipcode and SearchEngine will be utilized for a reverse geocoding function

# %%
# Set Up
import pandas as pd
import numpy as np

# GIS/Location Related"
#!pip install uszipcode
from uszipcode import Zipcode
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)


# Graphing
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10,10)
import seaborn as sns

# Regression
import statsmodels.api as sm

# %% [markdown]
# ## Reverse geocoder function
# Credits: https://stackoverflow.com/questions/60324730/reverse-geo-coding-without-google-api-for-zip-codes

# %%
def coord_to_zip(lat,lng):
    """ 
    Reverse geocoder that takes a lat and longitude value and finds the zipcode
    """
    zip_code = []
    for x,y in zip(lat,lng):
        result = search.by_coordinates(lat=x, lng=y, radius=14, returns=5)
        zip_code.append(result[0].zipcode)
    return zip_code

# %% [markdown]
# # Loading Data
# We will be using the cleaned data from Ro that has various ACS forms/Census forms compiled by zipcode. Learn more at the Data tab of the Notion page!
# https://github.com/Ro-Data/Ro-Census-Summaries-By-Zipcode/blob/master/
#
# * _income_ measures wealth and taxes by zipcode
# * _demo_ provides demographics by zipcode
# * _econ_ measures employment by zipcode
#
# For now, we're going to drop records with missing values.

# %%
income = pd.read_csv('../assorted_data/income_by_zip.csv')
income = income[['Zipcode','TotalWages']].rename({'Zipcode': 'Zip Code'}, axis = 1)

demo = pd.read_csv('../census_data/demo.txt', sep = '\t').dropna()
demo['Zip Code'] = demo['ZCTA5']

econ = pd.read_csv('../census_data/econ.txt', sep = '\t').dropna()
econ['Zip Code'] = demo['ZCTA5']

# %%
# The following hashed out code will reverse-geocode the GAMA data but
# due to the long run time.

# gama['Zip Code'] = coord_to_zip(gama['latitude'], gama['longitude'])
# gama.to_csv("gama_2019_geocoded.csv")


# Loads pre-geocoded GAMA data
gama = pd.read_csv('../gama_data/gama_2019_geocoded.csv').dropna(axis = 0)

# %% [markdown]
# # Cleaning and Wrangling
#
# ### Aggregating the number of tests and then counting

# %%
gama_test_counts = pd.DataFrame(gama.groupby(['Zip Code'])['results'].agg('count')).reset_index().astype(int)
gama_test_counts.head()
# Out:
#    Zip Code  results
# 0     91950       82
# 1     92058       82
# 2     92061       76
# 3     92071       74
# 4     92086      157

# %% [markdown]
# ### Merging the dataframes, then using more readable labels

# %%
gama_demo = pd.merge(left = gama_test_counts, right = demo, on = 'Zip Code')
g_d_econ  = pd.merge(left = gama_demo, right = econ, on = 'Zip Code')

final = g_d_econ.rename({'results': "Number of Tests",}, axis = 1)
final.shape
# Out:
# (18, 380)

# %% [markdown]
# # Checkpoint
#
# It is not ideal that we could only find information for 18 zip codes. A naive single-variable OLS will likely suffer from large standard errors. Luckily, the aim of this project is to _explore_ possible features rather than conclusively determine features. In the future, I would want to spend more time cleaning and exploring the data. Ideas I have currently are:
#
# 1. Running PCA on the 379 features and then cross validating to measure my error. I haven't investigated all the features and it might be that the census data is inherently low rank. For example, there may be many linear combinations of income measures.
# 2. Stepwise Regression, Backward Selection, or Forward Selection for feature selection
#
# However let's see if the data we have, again which is by zipcode, describes a region. For example, what if all the zipcodes were in the South Bay? From that perspective, we actually have as rich of a granularity we could ask for!
#
#
# Click Here to View in Your Browser
#  ==> https://www.easymapmaker.com/map/0191e9e8c3e6855fe1e390003db8c360

# %% [markdown]
# ![final_map](./images/final_map.png "Rough Plot of Final")

# %% [markdown]
# Nice! While a more rigorous data cleaning process could probability give us more results for more regions in California. This "EDA" of sorts provides the following insights
#
# * We can filter the 'final' dataframe for Fresno-tangent locations such that we could use our results to explain the Fresno region.
# * Future cleaning could allow us to create models and associative claims for regions within California
#
#
# # A Simple Model for Fresno, California
#
# Out of curiosity let's run a simple single-variable OLS and feature slection process for the sake of exploration. Zipcodes that are in Fresno and the 'final' dataframe begin with '93xxx'

# %%
fresno = final[final['Zip Code'] > 93000]

# %%
corr = fresno.corr()
corr_target = abs(corr["Number of Tests"])

#Selecting highly correlated features
relevant_features = corr_target[corr_target>0.5].index

# %% [markdown]
# # Running the OLS

# %%
Y = fresno[["Number of Tests"]]


X_train = fresno[['hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_other_total_population']]

X_with_const = sm.add_constant(X_train)

linear_model = sm.OLS(Y, X_with_const).fit()
linear_model.summary()
# Out:
# /Users/winsontruong/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/winsontruong/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Number of Tests   R-squared:                       0.271
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     3.726
# Date:                Fri, 29 May 2020   Prob (F-statistic):             0.0824
# Time:                        11:34:29   Log-Likelihood:                -61.280
# No. Observations:                  12   AIC:                             126.6
# Df Residuals:                      10   BIC:                             127.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================================================================================
#                                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                            81.7300     15.093      5.415      0.000      48.101     115.359
# hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_other_total_population     0.4366      0.226      1.930      0.082      -0.067       0.941
# ==============================================================================
# Omnibus:                        3.353   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.187   Jarque-Bera (JB):                1.492
# Skew:                           0.860   Prob(JB):                        0.474
# Kurtosis:                       3.165   Cond. No.                         79.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Regression + Random Forest = Regression Forest
#
# Thank you to William Koehrson for publishing a easy to follow guide on regression forest prediction! The following code has been adjusted from William's skeleton.
#
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0

# %%
outcome = final['Number of Tests']
features = final.iloc[:,3:]

# %%
from sklearn.model_selection import train_test_split

train_features, test_features, train_labels, test_labels = train_test_split(features, 
                                                                            outcome, 
                                                                            test_size = 0.25, 
                                                                            random_state = 142)

# %%
from sklearn.ensemble import RandomForestRegressor

# 1000 Decision Trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 142)

# Train the model on training data
rf.fit(train_features, train_labels)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=142, verbose=0,
#                       warm_start=False)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
squared_errors = (predictions - test_labels) ** 2

# Print out the mean absolute error (mae)
print('RMSE:', np.sqrt(np.mean(squared_errors)))
# Out:
# RMSE: 36.16875317176416

# %%
feature_list = list(features.columns)

# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:10} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-households_with_earnings-of-total_households Importance: 0.06
# Variable: commuting_to_work-percent-worked_at_home-of-workers_16_years_and_over Importance: 0.05
# Variable: race-population-one_race_american_indian_and_alaska_native_total_population Importance: 0.04
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_other_total_population Importance: 0.04
# Variable: sex_and_age-percent-35_to_44_years-of-total_population Importance: 0.03
# Variable: race-percent-one_race_american_indian_and_alaska_native-of-total_population Importance: 0.03
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-150000_to_199999-of-total_households Importance: 0.03
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_cash_public_assistance_income_dollars_households_with_cash_public_assistance_income Importance: 0.03
# Variable: race-population-one_race_native_hawaiian_and_other_pacific_islander_total_population Importance: 0.02
# Variable: race-percent-one_race_native_hawaiian_and_other_pacific_islander-of-total_population Importance: 0.02
# Variable: race_detailed-population-one_race_native_hawaiian_and_other_pacific_islander_guamanian_or_chamorro_total_population Importance: 0.02
# Variable: race_detailed-population-two_or_more_races-black_and_american_indian_and_alaska_native_total_population Importance: 0.02
# Variable: industry-population-wholesale_trade_civilian_employed_population_16_years_and_over Importance: 0.02
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-150000_to_199999-of-total_families Importance: 0.02
# Variable: health_insurance_coverage-percent-no_health_insurance-of-under_18_years_civilian_noninstitutionalized_population Importance: 0.02
# Variable: sex_and_age-population-5_to_9_years_total_population Importance: 0.01
# Variable: sex_and_age-percent-15_to_19_years-of-total_population Importance: 0.01
# Variable: sex_and_age-percent-25_to_34_years-of-total_population Importance: 0.01
# Variable: sex_and_age-population-75_to_84_years_total_population Importance: 0.01
# Variable: sex_and_age-percent-85_years_and_over-of-total_population Importance: 0.01
# Variable: race_detailed-population-one_race_american_indian_and_alaska_native_cherokee_tribal_grouping_total_population Importance: 0.01
# Variable: race_detailed-percent-one_race_asian_korean-of-total_population Importance: 0.01
# Variable: race-population-one_race_other_total_population Importance: 0.01
# Variable: race_detailed-percent-two_or_more_races-white_and_american_indian_and_alaska_native-of-total_population Importance: 0.01
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_black_total_population Importance: 0.01
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_other_total_population Importance: 0.01
# Variable: hispanic_or_latino_and_race_detailed-population-hispanic_or_latino_of_any_race_mexican_total_population Importance: 0.01
# Variable: hispanic_or_latino_and_race_detailed-population-hispanic_or_latino_of_any_race_other_total_population Importance: 0.01
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_two_or_more_races_including_some_other_race_total_population Importance: 0.01
# Variable: commuting_to_work-minutes-mean_travel_time_to_work_minutes Importance: 0.01
# Variable: industry-percent-construction-of-civilian_employed_population_16_years_and_over Importance: 0.01
# Variable: industry-percent-manufacturing-of-civilian_employed_population_16_years_and_over Importance: 0.01
# Variable: industry-percent-wholesale_trade-of-civilian_employed_population_16_years_and_over Importance: 0.01
# Variable: industry-percent-professional_scientific_and_management_and_administrative_and_waste_management_services-of-civilian_employed_population_16_years_and_over Importance: 0.01
# Variable: class_of_worker-percent-self_employed_in_own_not_incorporated_business_workers-of-civilian_employed_population_16_years_and_over Importance: 0.01
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-150000_to_199999_total_households Importance: 0.01
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-households_with_social_security-of-total_households Importance: 0.01
# Variable: health_insurance_coverage-percent-18_to_64_years_unemployed-of-civilian_noninstitutionalized_population Importance: 0.01
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families_with_female_householder_no_husband-of-all_families Importance: 0.01
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-related_children_under_5_years-of-all_people Importance: 0.01
# Variable: sex_and_age-population-total_population Importance: 0.0
# Variable: sex_and_age-population-male_total_population Importance: 0.0
# Variable: sex_and_age-percent-male-of-total_population Importance: 0.0
# Variable: sex_and_age-population-female_total_population Importance: 0.0
# Variable: sex_and_age-percent-female-of-total_population Importance: 0.0
# Variable: sex_and_age-population-under_5_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-under_5_years-of-total_population Importance: 0.0
# Variable: sex_and_age-percent-5_to_9_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-10_to_14_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-10_to_14_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-15_to_19_years_total_population Importance: 0.0
# Variable: sex_and_age-population-20_to_24_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-20_to_24_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-25_to_34_years_total_population Importance: 0.0
# Variable: sex_and_age-population-35_to_44_years_total_population Importance: 0.0
# Variable: sex_and_age-population-45_to_54_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-45_to_54_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-55_to_59_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-55_to_59_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-60_to_64_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-60_to_64_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-65_to_74_years_total_population Importance: 0.0
# Variable: sex_and_age-percent-65_to_74_years-of-total_population Importance: 0.0
# Variable: sex_and_age-percent-75_to_84_years-of-total_population Importance: 0.0
# Variable: sex_and_age-population-85_years_and_over_total_population Importance: 0.0
# Variable: sex_and_age-age-median_age_years_total_population Importance: 0.0
# Variable: sex_and_age-population-18_years_and_over_total_population Importance: 0.0
# Variable: sex_and_age-percent-18_years_and_over-of-total_population Importance: 0.0
# Variable: sex_and_age-population-21_years_and_over_total_population Importance: 0.0
# Variable: sex_and_age-percent-21_years_and_over-of-total_population Importance: 0.0
# Variable: sex_and_age-population-62_years_and_over_total_population Importance: 0.0
# Variable: sex_and_age-percent-62_years_and_over-of-total_population Importance: 0.0
# Variable: sex_and_age-population-65_years_and_over_total_population Importance: 0.0
# Variable: sex_and_age-percent-65_years_and_over-of-total_population Importance: 0.0
# Variable: sex_and_age-population-male_18_years_and_over_population Importance: 0.0
# Variable: sex_and_age-percent-male-of-18_years_and_over_population Importance: 0.0
# Variable: sex_and_age-population-female_18_years_and_over_population Importance: 0.0
# Variable: sex_and_age-percent-female-of-18_years_and_over_population Importance: 0.0
# Variable: sex_and_age-population-male_65_years_and_over_population Importance: 0.0
# Variable: sex_and_age-percent-male-of-65_years_and_over_population Importance: 0.0
# Variable: sex_and_age-population-female_65_years_and_over_population Importance: 0.0
# Variable: sex_and_age-percent-female-of-65_years_and_over_population Importance: 0.0
# Variable: race-population-total_population Importance: 0.0
# Variable: race-population-one_race_total_population Importance: 0.0
# Variable: race-percent-one_race-of-total_population Importance: 0.0
# Variable: race-population-two_or_more_races_total_population Importance: 0.0
# Variable: race-percent-two_or_more_races-of-total_population Importance: 0.0
# Variable: race-population-one_race_white_total_population Importance: 0.0
# Variable: race-percent-one_race_white-of-total_population Importance: 0.0
# Variable: race-population-one_race_black_total_population Importance: 0.0
# Variable: race-percent-one_race_black-of-total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_american_indian_and_alaska_native_cherokee_tribal_grouping-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_american_indian_and_alaska_native_chippewa_tribal_grouping_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_american_indian_and_alaska_native_chippewa_tribal_grouping-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_american_indian_and_alaska_native_navajo_tribal_grouping_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_american_indian_and_alaska_native_navajo_tribal_grouping-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_american_indian_and_alaska_native_sioux_tribal_grouping_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_american_indian_and_alaska_native_sioux_tribal_grouping-of-total_population Importance: 0.0
# Variable: race-population-one_race_asian_total_population Importance: 0.0
# Variable: race-percent-one_race_asian-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_indian_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_indian-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_chinese_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_chinese-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_filipino_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_filipino-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_japanese_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_japanese-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_korean_total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_vietnamese_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_vietnamese-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_asian_other_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_asian_other-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_native_hawaiian_and_other_pacific_islander_native_hawaiian_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_native_hawaiian_and_other_pacific_islander_native_hawaiian-of-total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_native_hawaiian_and_other_pacific_islander_guamanian_or_chamorro-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_native_hawaiian_and_other_pacific_islander_samoan_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_native_hawaiian_and_other_pacific_islander_samoan-of-total_population Importance: 0.0
# Variable: race_detailed-population-one_race_native_hawaiian_and_other_pacific_islander_other_pacific_islander_total_population Importance: 0.0
# Variable: race_detailed-percent-one_race_native_hawaiian_and_other_pacific_islander_other_pacific_islander-of-total_population Importance: 0.0
# Variable: race-percent-one_race_other-of-total_population Importance: 0.0
# Variable: race_detailed-population-two_or_more_races-white_and_black_total_population Importance: 0.0
# Variable: race_detailed-percent-two_or_more_races-white_and_black-of-total_population Importance: 0.0
# Variable: race_detailed-population-two_or_more_races-white_and_american_indian_and_alaska_native_total_population Importance: 0.0
# Variable: race_detailed-population-two_or_more_races-white_and_asian_total_population Importance: 0.0
# Variable: race_detailed-percent-two_or_more_races-white_and_asian-of-total_population Importance: 0.0
# Variable: race_detailed-percent-two_or_more_races-black_and_american_indian_and_alaska_native-of-total_population Importance: 0.0
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_white_total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_white-of-total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_black-of-total_population Importance: 0.0
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_american_indian_and_alaska_native_total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_american_indian_and_alaska_native-of-total_population Importance: 0.0
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_asian_total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_asian-of-total_population Importance: 0.0
# Variable: race_detailed-population-race_alone_or_in_combination_with_one_or_more_other_races_native_hawaiian_and_other_pacific_islander_total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_native_hawaiian_and_other_pacific_islander-of-total_population Importance: 0.0
# Variable: race_detailed-percent-race_alone_or_in_combination_with_one_or_more_other_races_other-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-population-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-population-hispanic_or_latino_of_any_race_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-percent-hispanic_or_latino_of_any_race-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-hispanic_or_latino_of_any_race_mexican-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-hispanic_or_latino_of_any_race_puerto_rican_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-hispanic_or_latino_of_any_race_puerto_rican-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-hispanic_or_latino_of_any_race_cuban_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-hispanic_or_latino_of_any_race_cuban-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-hispanic_or_latino_of_any_race_other-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-population-not_hispanic_or_latino_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-percent-not_hispanic_or_latino-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_white_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_white-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_black_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_black-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_american_indian_and_alaska_native_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_american_indian_and_alaska_native-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_asian_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_asian-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_native_hawaiian_and_other_pacific_islander_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_native_hawaiian_and_other_pacific_islander-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_other-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_two_or_more_races_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_two_or_more_races-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_two_or_more_races_including_some_other_race-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-population-not_hispanic_or_latino_two_or_more_races_excluding_some_other_race_and_three_or_more_races_total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race_detailed-percent-not_hispanic_or_latino_two_or_more_races_excluding_some_other_race_and_three_or_more_races-of-total_population Importance: 0.0
# Variable: hispanic_or_latino_and_race-housing_units-total_housing_units Importance: 0.0
# Variable: citizen_voting_age_population-population-citizen_18_and_over_population Importance: 0.0
# Variable: citizen_voting_age_population-population-male_citizen_18_and_over_population Importance: 0.0
# Variable: citizen_voting_age_population-percent-male-of-citizen_18_and_over_population Importance: 0.0
# Variable: citizen_voting_age_population-population-female_citizen_18_and_over_population Importance: 0.0
# Variable: citizen_voting_age_population-percent-female-of-citizen_18_and_over_population Importance: 0.0
# Variable: ZCTA5_y    Importance: 0.0
# Variable: employment_status-population-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-in_labor_force_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-in_labor_force-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-in_civilian_labor_force_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-in_civilian_labor_force-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-employed_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-employed-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-unemployed_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-unemployed-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-armed_forces_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-armed_forces-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-population-not_in_labor_force_population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-not_in_labor_force-of-population_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-unemployed-of-civilian_labor_force_population_16_years_and_over Importance: 0.0
# Variable: employment_status-population_females_16_years_and_over Importance: 0.0
# Variable: employment_status-population-in_labor_force_females_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-in_labor_force-of-females_16_years_and_over Importance: 0.0
# Variable: employment_status-population-in_civilian_labor_force_females_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-in_civilian_labor_force-of-females_16_years_and_over Importance: 0.0
# Variable: employment_status-population-employed_females_16_years_and_over Importance: 0.0
# Variable: employment_status-percent-employed-of-females_16_years_and_over Importance: 0.0
# Variable: employment_status-population_own_children_of_the_householder_under_6_years Importance: 0.0
# Variable: employment_status-population-all_parents_in_family_in_labor_force_own_children_of_the_householder_under_6_years Importance: 0.0
# Variable: employment_status-percent-all_parents_in_family_in_labor_force-of-own_children_of_the_householder_under_6_years Importance: 0.0
# Variable: employment_status-population_own_children_of_the_householder_6_to_17_years Importance: 0.0
# Variable: employment_status-population-all_parents_in_family_in_labor_force_own_children_of_the_householder_6_to_17_years Importance: 0.0
# Variable: employment_status-percent-all_parents_in_family_in_labor_force-of-own_children_of_the_householder_6_to_17_years Importance: 0.0
# Variable: commuting_to_work-population_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-car_truck_or_van_alone_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-percent-car_truck_or_van_alone-of-workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-car_truck_or_van_carpooled_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-percent-car_truck_or_van_carpooled-of-workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-public_transportation_excluding_taxicab_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-percent-public_transportation_excluding_taxicab-of-workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-walked_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-percent-walked-of-workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-other_means_workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-percent-other_means-of-workers_16_years_and_over Importance: 0.0
# Variable: commuting_to_work-population-worked_at_home_workers_16_years_and_over Importance: 0.0
# Variable: occupation-population-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-population-management_business_science_and_arts_occupations_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-percent-management_business_science_and_arts_occupations-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-population-service_occupations_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-percent-service_occupations-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-population-sales_and_office_occupations_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-percent-sales_and_office_occupations-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-population-natural_resources_construction_and_maintenance_occupations_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-percent-natural_resources_construction_and_maintenance_occupations-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-population-production_transportation_and_material_moving_occupations_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: occupation-percent-production_transportation_and_material_moving_occupations-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-agriculture_forestry_fishing_and_hunting_and_mining_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-agriculture_forestry_fishing_and_hunting_and_mining-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-construction_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-manufacturing_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-retail_trade_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-retail_trade-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-transportation_and_warehousing_and_utilities_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-transportation_and_warehousing_and_utilities-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-information_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-information-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-finance_and_insurance_and_real_estate_and_rental_and_leasing_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-finance_and_insurance_and_real_estate_and_rental_and_leasing-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-professional_scientific_and_management_and_administrative_and_waste_management_services_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-educational_services_and_health_care_and_social_assistance_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-educational_services_and_health_care_and_social_assistance-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-arts_entertainment_and_recreation_and_accommodation_and_food_services_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-arts_entertainment_and_recreation_and_accommodation_and_food_services-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-other_services_except_public_administration_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-other_services_except_public_administration-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-population-public_administration_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: industry-percent-public_administration-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-population-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-population-private_wage_and_salary_workers_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-percent-private_wage_and_salary_workers-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-population-government_workers_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-percent-government_workers-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-population-self_employed_in_own_not_incorporated_business_workers_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-population-unpaid_family_workers_civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: class_of_worker-percent-unpaid_family_workers-of-civilian_employed_population_16_years_and_over Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-less_than_10000_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-less_than_10000-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-10000_to_14999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-10000_to_14999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-15000_to_24999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-15000_to_24999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-25000_to_34999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-25000_to_34999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-35000_to_49999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-35000_to_49999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-50000_to_74999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-50000_to_74999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-75000_to_99999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-75000_to_99999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-100000_to_149999_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-100000_to_149999-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-200000_or_more_total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-200000_or_more-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_household_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_household_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_earnings Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_earnings_dollars_households_with_earnings Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_social_security Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_social_security_income_dollars_households_with_social_security Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_retirement_income Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-households_with_retirement_income-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-mean_retirement_income_dollars_households_with_retirement_income Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_supplemental_security_income Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-households_with_supplemental_security_income-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_supplemental_security_income_dollars_households_with_supplemental_security_income Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_cash_public_assistance_income Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-with_cash_public_assistance_income-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-households_with_food_stampsnap_benefits_in_the_past_12_months Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-households_with_food_stampsnap_benefits_in_the_past_12_months-of-total_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-less_than_10000_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-less_than_10000-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-10000_to_14999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-10000_to_14999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-15000_to_24999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-15000_to_24999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-25000_to_34999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-25000_to_34999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-35000_to_49999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-35000_to_49999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-50000_to_74999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-50000_to_74999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-75000_to_99999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-75000_to_99999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-100000_to_149999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-100000_to_149999-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-150000_to_199999_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-families-200000_or_more_total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-percent-200000_or_more-of-total_families Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_family_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_family_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-per_capita_family_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-households-nonfamily_households Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_nonfamily_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-mean_nonfamily_income_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_workers_earnings_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_male_full-time_year_round_workers_earnings_dollars Importance: 0.0
# Variable: income_and_benefits_in_2016_inflation_adjusted_dollars-dollars-median_female_full-time_year_round_workers_earnings_dollars Importance: 0.0
# Variable: health_insurance_coverage-population-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_health_insurance_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_health_insurance-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_private_health_insurance_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_private_health_insurance-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_public_health_insurance_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_public_health_insurance-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-no_health_insurance_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-no_health_insurance-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-under_18_years_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-under_18_years-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-no_health_insurance_under_18_years_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-18_to_64_years_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-18_to_64_years-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-18_to_64_years_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-18_to_64_years_in_labor_force-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-18_to_64_years_employed-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_health_insurance_18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_health_insurance-of-18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_private_health_insurance_18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_private_health_insurance-of-18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_public_health_insurance_18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_public_health_insurance-of-18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-no_health_insurance_18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-no_health_insurance-of-18_to_64_years_employed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_health_insurance_18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_health_insurance-of-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_private_health_insurance_18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_private_health_insurance-of-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_public_health_insurance_18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_public_health_insurance-of-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-no_health_insurance-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-no_health_insurance-of-18_to_64_years_unemployed_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-18_to_64_years_not_in_labor_force-of-civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_health_insurance_18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_health_insurance-of-18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_private_health_insurance_18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_private_health_insurance-of-18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-with_public_health_insurance_18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-with_public_health_insurance-of-18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-population-no_health_insurance_18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: health_insurance_coverage-percent-no_health_insurance-of-18_to_64_years_not_in_labor_force_civilian_noninstitutionalized_population Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families_with_under_18_years_related_children-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families_with_under_5_years_only_related_children-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-married_couple_families-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-married_couple_families_with_under_18_years_related_children-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-married_couple_families_with_5_years_only_related_children_under-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families_with_female_householder_no_husband_with_under_18_years_related_children-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-families_with_female_householder_no_husband_with_under_5_years_only_related_children-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-people-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-under_18_years-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-related_children_under_18_years-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-related_children_5_to_17_years-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-18_years_and_over-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-18_to_64_years-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-65_years_and_over-of-all_people Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-people_in_families-of-all_families Importance: 0.0
# Variable: people_whose_income_in_past_12m_is_below_poverty_level-percent-unrelated_individuals_15_years_and_over-of-all_families Importance: 0.0

# %% [markdown]
# That's a bit messy so let's clean that up and visualize.

# %%
impt_features = pd.DataFrame(columns = ['Features', 'Importance'])

# Manually naming the features
impt_features['Features'] = ['Income per Household',
                            '% of Commuters relative to WFH',
                            'Number of American Indian and Alaskan Native',
                             'Number of Hispanic/Latino identifying',
                            'Percentage of 35-44 Year Olds',
                            '% of American Indian and Alaskan Natives',
                            'Income per Household 3',
                            'Income per Household w/ Public Assistance',
                            'Number of Native Hawaiians',
                            '% of Native Hawaiins',
                            'Other Pacific Islanders']

impt_features['Importance'] = [i[1] for i in feature_importances][0:11]

impt_features
# Out:
#                                         Features  Importance
# 0                           Income per Household        0.06
# 1                 % of Commuters relative to WFH        0.05
# 2   Number of American Indian and Alaskan Native        0.04
# 3          Number of Hispanic/Latino identifying        0.04
# 4                  Percentage of 35-44 Year Olds        0.03
# 5       % of American Indian and Alaskan Natives        0.03
# 6                         Income per Household 3        0.03
# 7      Income per Household w/ Public Assistance        0.03
# 8                     Number of Native Hawaiians        0.02
# 9                           % of Native Hawaiins        0.02
# 10                       Other Pacific Islanders        0.02

# %% [markdown]
# # Analysis
# Thanks to William's help, the table above tells us the Top 10 most important features in terms of predicting the number of tests per zipcode. While the names have been simplified and further work would be necessary to fully understand the American Community Survey metric (FIPS code) meaning, in general we have astounding evidence for our hypothesis.
#
# Of the top 10 most important features, we see _historically_ marginalized populations such as Native Americans, Alaskan Natives, and Native Hawaiian identifying populations being significant as well as those who are on some form of public assistance such as Medicare/Medicaid.

# %%
sns.barplot(y = 'Features', x = 'Importance', data = impt_features, orient = 'h')
plt.title('Top 10 Features in Determining the Number of Groundwater Tests per Zipcode from the Random Forest Model')
# Out:
# Text(0.5, 1.0, 'Top 10 Features in Determining the Number of Groundwater Tests per Zipcode from the Random Forest Model')

# %% [markdown]
# # References
# * PCA and Small Sample Sizes https://stats.stackexchange.com/questions/116132/regression-with-very-small-sample-size
#
# * Feature Selection https://towardsdatascience.com/feature-selection-techniques-in-regression-model-26878fe0e24e
